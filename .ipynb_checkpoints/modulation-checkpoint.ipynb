# %%
import numpy as np
import scipy 
import matplotlib.pyplot as plt
import pandas as pd

# %%
np_list_germanium= np.loadtxt("germanium1.txt")

plt.figure()  #Need this before we are able to save a plot to file!!!

germanium_volt= plt.plot(np_list_germanium[:,0],np_list_germanium[:,1],label="voltin",alpha=.5)
#germanium_voltout=plt.plot(np_list_germanium[:,1],label="voltout",alpha=.5)


#plt.legend()
plt.title("Diode")
  

 
plt.savefig('diode.png')
